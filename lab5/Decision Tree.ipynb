# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %%
#Import the Necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
#Load the data sets- train and test 
# Load the dataset
train_df = pd.read_csv("train.csv")

# Split the data into training (80%) and testing (20%) sets
train_data, test_data = train_test_split(train_df, test_size=0.2, random_state=42)

# %%
#Look at top values of train data 
print(train_data.head())
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 331          332         0       1                 Partner, Mr. Austen
# 733          734         0       2          Berriman, Mr. William John
# 382          383         0       3                  Tikkanen, Mr. Juho
# 704          705         0       3             Hansen, Mr. Henrik Juul
# 813          814         0       3  Andersson, Miss. Ebba Iris Alfrida
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 331    male  45.5      0      0             113043  28.5000  C124        S
# 733    male  23.0      0      0              28425  13.0000   NaN        S
# 382    male  32.0      0      0  STON/O 2. 3101293   7.9250   NaN        S
# 704    male  26.0      1      0             350025   7.8542   NaN        S
# 813  female   6.0      4      2             347082  31.2750   NaN        S

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Print the column names of train data

train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Print the dimension of train and test data
print("dimensions of train data:",train_data.shape,"\n","dimensions of test_data:",test_data)
# Out:
# dimensions of train data: (712, 12)
#  dimensions of test_data:      PassengerId  Survived  Pclass  \
# 709          710         1       3
# 439          440         0       2
# 840          841         0       3
# 720          721         1       2
# 39            40         1       3
# ..           ...       ...     ...
# 433          434         0       3
# 773          774         0       3
# 25            26         1       3
# 84            85         1       2
# 10            11         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 709  Moubarek, Master. Halim Gonios ("William George")    male   NaN      1
# 439             Kvillner, Mr. Johan Henrik Johannesson    male  31.0      0
# 840                        Alhomaki, Mr. Ilmari Rudolf    male  20.0      0
# 720                  Harper, Miss. Annie Jessie "Nina"  female   6.0      0
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 433                         Kallio, Mr. Nikolai Erland    male  17.0      0
# 773                                    Elias, Mr. Dibo    male   NaN      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 84                                 Ilett, Miss. Bertha  female  17.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#      Parch             Ticket     Fare Cabin Embarked
# 709      1               2661  15.2458   NaN        C
# 439      0         C.A. 18723  10.5000   NaN        S
# 840      0   SOTON/O2 3101287   7.9250   NaN        S
# 720      1             248727  33.0000   NaN        S
# 39       0               2651  11.2417   NaN        C
# ..     ...                ...      ...   ...      ...
# 433      0  STON/O 2. 3101274   7.1250   NaN        S
# 773      0               2674   7.2250   NaN        C
# 25       5             347077  31.3875   NaN        S
# 84       0         SO/C 14885  10.5000   NaN        S
# 10       1            PP 9549  16.7000    G6        S
#
# [179 rows x 12 columns]

# %%
#Print the number of missing values in each column of train and test data
print("missing values in train data:", train_data.isnull().sum(),"\n","\n","\n",
      "Missing values of test data:", test_data.isnull().sum())
# Out:
# missing values in train data: PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            140
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          553
# Embarked         2
# dtype: int64
#
#
#  Missing values of test data: PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             37
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          134
# Embarked         0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#Barchart of Survived, Pclass, Sex, Embarked
# Bar charts for categorical variables
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
sns.countplot(x='Survived', data=train_data, ax=axes[0, 0])
axes[0, 0].set_title('Survival Count')
sns.countplot(x='Pclass', data=train_data, ax=axes[0, 1])
axes[0, 1].set_title('Passenger Class Count')
sns.countplot(x='Sex', data=train_data, ax=axes[1, 0])
axes[1, 0].set_title('Gender Count')
sns.countplot(x='Embarked', data=train_data, ax=axes[1, 1])
axes[1, 1].set_title('Embarked Count')
plt.tight_layout()
plt.show()

# %%
#Histogram of Age, Parch, Fare
# Histogram of Age, Parch, Fare
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
sns.histplot(train_data['Age'].dropna(), bins=30, ax=axes[0], kde=True)
axes[0].set_title('Age Distribution')
sns.histplot(train_data['Parch'], bins=30, ax=axes[1], kde=True)
axes[1].set_title('Parch Distribution')
sns.histplot(train_data['Fare'], bins=30, ax=axes[2], kde=True)
axes[2].set_title('Fare Distribution')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
train_data = pd.read_csv('train.csv')

# Plot histogram of Age for Survived and Did Not Survive
plt.figure(figsize=(10, 5))
sns.histplot(train_data[train_data['Survived'] == 1]['Age'].dropna(), bins=30, color='green', label='Survived', kde=True)
sns.histplot(train_data[train_data['Survived'] == 0]['Age'].dropna(), bins=30, color='blue', label='Did Not Survive', kde=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution by Survival Status')
plt.legend()
plt.show()

# %%
#Histogram of Age of the given data set(sample)
plt.figure(figsize=(12,10))
sns.histplot(train_data["Age"].dropna(), bins=30,color="green", kde=True)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("age wise distribution of given data")
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace the msiing values in Embarked column by 'S'
train_data["Embarked"].fillna("S", inplace=True)
test_data["Embarked"].fillna("S", inplace=True)

# %%
#Impute the missing values in Fare column with median value
train_data["Fare"].fillna(train_data["Fare"].median(), inplace=True)
test_data["Fare"].fillna(test_data["Fare"].median(), inplace=True)

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data

mean_age=train_data["Age"].mean()
std_age=train_data["Age"].std()
nan_count=train_data["Age"].isnull().sum()
train_data.loc[train_data["Age"].isnull(),"Age"]=np.random.normal(mean_age, std_age, nan_count)

test_mean_age=test_data["Age"].mean()
test_std_age=test_data["Age"].std()
test_nan_count=test_data["Age"].isnull().sum()
test_data.loc[test_data["Age"].isnull(), "Age"]=np.random.normal(test_mean_age, test_std_age, test_nan_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 #Impute the Age column. It has too many missing values but it may be important.
#       2 #We fill the missing values with numbers randomly drawn from distribution
#       3 #that has same mean and standard deviation as non missing Age data
# ----> 5 mean_age=train_data["Age"].mean()
#       6 std_age=train_data["Age"].std()
#       7 nan_count=train_data["Age"].isnull().sum()
#
# NameError: name 'train_data' is not defined

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch + SibSp + 1

train_data["FamilySize"]=train_data["SibSp"]+train_data["Parch"]+1
test_data["FamilySize"]=test_data["SibSp"]+test_data["Parch"]+1

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False
train_data["IsAlone"]=train_data["FamilySize"]==1
test_data["IsAlone"]=test_data["FamilySize"]==1

# %% [markdown]
# ## Create a new attribute Has_cabin using the attribue Cabin.
# #if Cabin == NaN the Has_cabin = False else Has_cabin = True

# %%
#Create a new attribute Has_cabin using the attribue Cabin.

#if Cabin == NaN the Has_cabin = False else Has_cabin = True
train_data['Has_cabin'] = train_data['Cabin'].notna()
test_data['Has_cabin'] = test_data['Cabin'].notna()

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId, Name, Ticket, and Cabin

train_data.drop(columns=["PassengerId", "Name", "Ticket", "Cabin"], inplace=True)
test_data.drop(columns=["PassengerId", "Name", "Ticket", "Cabin"], inplace=True)

# %% [markdown]
# ## Model Building

# %%
#Prepare X and y
X= train_data.drop(columns=["Survived"])
y=train_data["Survived"]

# %%
# Label encoding of categorical features
# Label encoding of categorical features
label_encoders = {}
categorical_features = ['Sex', 'Embarked']

for col in categorical_features:
    le = LabelEncoder()
    train_data[col] = le.fit_transform(train_data[col])
    test_data[col] = le.transform(test_data[col])
    label_encoders[col] = le

# %%
# concat df_categorical with original df
# Concatenate df_categorical with the original dataframe
# Concatenate df_categorical with the original dataframe
# Perform one-hot encoding for categorical features
df_categorical = pd.get_dummies(train_data[['Sex', 'Embarked']], drop_first=True)
train_data = pd.concat([train_data.drop(columns=['Sex', 'Embarked']), df_categorical], axis=1)

df_categorical_test = pd.get_dummies(test_data[['Sex', 'Embarked']], drop_first=True)
test_data = pd.concat([test_data.drop(columns=['Sex', 'Embarked']), df_categorical_test], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # concat df_categorical with original df
#       2 # Concatenate df_categorical with the original dataframe
#       3 # Concatenate df_categorical with the original dataframe
#       4 # Perform one-hot encoding for categorical features
# ----> 5 df_categorical = pd.get_dummies(train_data[['Sex', 'Embarked']], drop_first=True)
#       6 train_data = pd.concat([train_data.drop(columns=['Sex', 'Embarked']), df_categorical], axis=1)
#       8 df_categorical_test = pd.get_dummies(test_data[['Sex', 'Embarked']], drop_first=True)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv("train.csv")  # Ensure the correct path to the file
df.head()  # Display first few rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Do a pairplot of all features
sns.pairplot(df, diag_kind='kde')
plt.show()

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation
X = df.drop(columns=["target_column"])  # Replace "target_column" with actual target column name
y = df["target_column"]

X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Splitting the data into train and validation set - 90% train 10% validation
#       2 #X_train, X_test, y_train, y_validation
# ----> 3 X = df.drop(columns=["target_column"])  # Replace "target_column" with actual target column name
#       4 y = df["target_column"]
#       6 X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['target_column'] not found in axis"

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       1 # Create the model
#       2 # Fitting the decision tree with default hyperparameters
#       3 # Importing decision tree classifier from sklearn library
#       4 model = DecisionTreeClassifier(random_state=42)
# ----> 5 model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
#Print the tree

# Importing required packages for visualization
plt.figure(figsize=(20,10))
plot_tree(model, filled=True, feature_names=X.columns, class_names=str(np.unique(y)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       1 #Print the tree
#       2
#       3 # Importing required packages for visualization
#       4 plt.figure(figsize=(20,10))
# ----> 5 plot_tree(model, filled=True, feature_names=X.columns, class_names=str(np.unique(y)))
#       6 plt.show()
#
# NameError: name 'X' is not defined

# %%
# plotting tree with max_depth=3
plt.figure(figsize=(15,8))
plot_tree(model, filled=True, feature_names=X.columns, class_names=str(np.unique(y)), max_depth=3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 # plotting tree with max_depth=3
#       2 plt.figure(figsize=(15,8))
# ----> 3 plot_tree(model, filled=True, feature_names=X.columns, class_names=str(np.unique(y)), max_depth=3)
#       4 plt.show()
#
# NameError: name 'X' is not defined

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report
y_pred = model.predict(X_validation)

# %%
# Printing confusion matrix and accuracy
print("Classification Report:\n", classification_report(y_validation, y_pred))

print("Confusion Matrix:\n", confusion_matrix(y_validation, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Printing confusion matrix and accuracy
# ----> 2 print("Classification Report:\n", classification_report(y_validation, y_pred))
#       4 print("Confusion Matrix:\n", confusion_matrix(y_validation, y_pred))
#
# NameError: name 'y_validation' is not defined

# %%
accuracy = accuracy_score(y_validation, y_pred)
precision = precision_score(y_validation, y_pred, average='weighted')
recall = recall_score(y_validation, y_pred, average='weighted')
f1 = f1_score(y_validation, y_pred, average='weighted')

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 accuracy = accuracy_score(y_validation, y_pred)
#       2 precision = precision_score(y_validation, y_pred, average='weighted')
#       3 recall = recall_score(y_validation, y_pred, average='weighted')
#
# NameError: name 'y_validation' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Load your dataset (Replace with actual dataset)
#df = pd.read_csv('your_dataset.csv')

# Example dataset (Iris dataset) for demonstration
from sklearn.datasets import load_iris
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target  # Target variable

# Step 1: Check and Clean Column Names
print("Column Names Before Cleaning:", df.columns)
df.columns = df.columns.str.strip()  # Remove extra spaces

# Step 2: Verify Target Column Exists
print("Updated Column Names:", df.columns)
target_col = "target"  # Replace with actual column name if different

# Step 3: Pairplot for Feature Visualization
sns.pairplot(df, hue=target_col)
plt.show()

# Step 4: Splitting Data into Train (90%) & Validation (10%) sets
X = df.drop(columns=[target_col])
y = df[target_col]
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42)

# Step 5: Creating and Training Decision Tree Model
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Step 6: Visualizing Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(model, filled=True, feature_names=X.columns, class_names=[str(i) for i in df[target_col].unique()])
plt.show()

# Step 7: Model Predictions
y_pred = model.predict(X_validation)

# Step 8: Evaluation Metrics
print("\nClassification Report:\n", classification_report(y_validation, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_validation, y_pred))

# Accuracy Score
accuracy = accuracy_score(y_validation, y_pred)
print(f"\nAccuracy: {accuracy:.4f}")

# Extracting Precision, Recall, and F1-score
report = classification_report(y_validation, y_pred, output_dict=True)
precision = report['accuracy']
recall = report['macro avg']['recall']
f1_score = report['macro avg']['f1-score']

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Column Names Before Cleaning: Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')
# Updated Column Names: Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00         3
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15
#
#
# Confusion Matrix:
#  [[6 0 0]
#  [0 6 0]
#  [0 0 3]]
#
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
